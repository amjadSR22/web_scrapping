# %%
#import libraries
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen # for connection

# %%
url = 'https://www.rottentomatoes.com/browse/movies_at_home/affiliates:netflix?page=1'

# %%
# movie at home june 2022 
data = urlopen(url)

# %%
# getting the html code for full page 
data_html = data.read()

# %%
data_html
# Out:
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr" xmlns="http://www.w3.org/1999/xhtml" prefix="fb: http://www.facebook.com/2008/fbml og: http://opengraphprotocol.org/schema/">\n    <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">\n        \n\n        \n            <script src="/assets/pizza-pie/javascripts/bundles/roma/rt-common.js?single"></script>\n        \n        <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n        <meta http-equiv="x-ua-compatible" content="ie=edge">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n\n        <title>Movies at Home on Netflix (September 2022) - Rotten Tomatoes</title>\n        <meta name="description" content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies & TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets">\n\n        \n            <link rel="canonical" href="https://www.rottentom
# ...

# %%
# closing the request 
data.close()

# %%
# creating an html parsing 
data_parsing = bs(data_html, "html.parser")
data_parsing
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en" prefix="fb: http://www.facebook.com/2008/fbml og: http://opengraphprotocol.org/schema/" xmlns="http://www.w3.org/1999/xhtml">
# <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
# <script src="/assets/pizza-pie/javascripts/bundles/roma/rt-common.js?single"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Movies at Home on Netflix (September 2022) - Rotten Tomatoes</title>
# <meta content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies &amp; TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets" name="description"/>
# <link href="https://www.rottentomatoes.com/browse/movies_at_home/affiliates:netflix" rel="canonical"/>
# ...

# %%
data_find = data_parsing.find_all("div", {"slot":"caption"})
data_find
# Out:
# [<div data-qa="discovery-media-list-item-caption" data-track="scores" slot="caption">
#  <score-pairs replace-attribute="" replace-attribute-audiencescore="media.audienceScore.score" replace-attribute-audiencesentiment="media.audienceScore.sentiment" replace-attribute-criticscertified="media.criticsScore.certifiedAttribute" replace-attribute-criticsscore="media.criticsScore.score" replace-attribute-criticssentiment="media.criticsScore.sentiment">
#  </score-pairs><span class="p--small" data-qa="discovery-media-list-item-title" replace-innertext="">
#              {{ media.title }}
#          </span>
#  <span show-else="else-1" show-if="media.releaseDateText"><span class="smaller" data-qa="discovery-media-list-item-start-date" replace-innertext="">
#              {{ media.releaseDateText }}
#            </span>
#  </span>
#  </div>,
#  <div data-qa="discovery-media-list-item-caption" data-track="scores" slot="caption">
# ...

# %%
len(data_find)
# Out:
# 31

# %%
#Scraping the name of movie at this page

# %%
name_of_movie_1 = data_find[1].find_all("span" , {"class":"p--small"})
name_1 = name_of_movie_1[0].text.strip()
name_of_movie_2 = data_find[2].find_all("span" , {"class":"p--small"})
name_2 = name_of_movie_2[0].text.strip()
name_of_movie_3 = data_find[3].find_all("span" , {"class":"p--small"})
name_3 = name_of_movie_3[0].text.strip()
name_of_movie_4 = data_find[4].find_all("span" , {"class":"p--small"})
name_4 = name_of_movie_4[0].text.strip()
name_of_movie_5 = data_find[5].find_all("span" , {"class":"p--small"})
name_5 = name_of_movie_5[0].text.strip()
name_of_movie_6 = data_find[6].find_all("span" , {"class":"p--small"})
name_6 = name_of_movie_6[0].text.strip()
name_of_movie_7 = data_find[7].find_all("span" , {"class":"p--small"})
name_7 = name_of_movie_7[0].text.strip()
name_of_movie_8 = data_find[8].find_all("span" , {"class":"p--small"})
name_8 = name_of_movie_8[0].text.strip()
name_of_movie_9 = data_find[9].find_all("span" , {"class":"p--small"})
name_9 = name_of_movie_9[0].text.strip()
name_of_movie_10= data_find[10].find_all("span" , {"class":"p--small"})
name_10 = name_of_movie_10[0].text.strip()
name_of_movie_11 = data_find[11].find_all("span" , {"class":"p--small"})
name_11 = name_of_movie_11[0].text.strip()
name_of_movie_12 = data_find[12].find_all("span" , {"class":"p--small"})
name_12 = name_of_movie_12[0].text.strip()
name_of_movie_13 = data_find[13].find_all("span" , {"class":"p--small"})
name_13 = name_of_movie_13[0].text.strip()
name_of_movie_14 = data_find[14].find_all("span" , {"class":"p--small"})
name_14 = name_of_movie_14[0].text.strip()
name_of_movie_15 = data_find[15].find_all("span" , {"class":"p--small"})
name_15 = name_of_movie_15[0].text.strip()
name_of_movie_16 = data_find[16].find_all("span" , {"class":"p--small"})
name_16 = name_of_movie_16[0].text.strip()
name_of_movie_17 = data_find[17].find_all("span" , {"class":"p--small"})
name_17 = name_of_movie_17[0].text.strip()
name_of_movie_18 = data_find[18].find_all("span" , {"class":"p--small"})
name_18 = name_of_movie_18[0].text.strip()
name_of_movie_19 = data_find[19].find_all("span" , {"class":"p--small"})
name_19 = name_of_movie_19[0].text.strip()
name_of_movie_20 = data_find[20].find_all("span" , {"class":"p--small"})
name_20 = name_of_movie_20[0].text.strip()
name_of_movie_21 = data_find[21].find_all("span" , {"class":"p--small"})
name_21 = name_of_movie_21[0].text.strip()
name_of_movie_22 = data_find[22].find_all("span" , {"class":"p--small"})
name_22 = name_of_movie_22[0].text.strip()
name_of_movie_23 = data_find[23].find_all("span" , {"class":"p--small"})
name_23 = name_of_movie_23[0].text.strip()
name_of_movie_24 = data_find[24].find_all("span" , {"class":"p--small"})
name_24 = name_of_movie_24[0].text.strip()
name_of_movie_25 = data_find[25].find_all("span" , {"class":"p--small"})
name_25 = name_of_movie_25[0].text.strip()
name_of_movie_26 = data_find[26].find_all("span" , {"class":"p--small"})
name_26= name_of_movie_26[0].text.strip()
name_of_movie_27 = data_find[27].find_all("span" , {"class":"p--small"})
name_27= name_of_movie_27[0].text.strip()
name_of_movie_28= data_find[28].find_all("span" , {"class":"p--small"})
name_28 = name_of_movie_28[0].text.strip()
name_of_movie_29 = data_find[29].find_all("span" , {"class":"p--small"})
name_29 = name_of_movie_29[0].text.strip()
name_of_movie_30 = data_find[30].find_all("span" , {"class":"p--small"})
name_30 = name_of_movie_30[0].text.strip()

# %%
# Scraping date of movie

# %%
date_1 = data_find[1].find_all("span" , {"class":"smaller"})
da_1 = date_1[0].text.strip()
date_2 = data_find[2].find_all("span" , {"class":"smaller"})
da_2 = date_2[0].text.strip()
date_3 = data_find[3].find_all("span" , {"class":"smaller"})
da_3 = date_3[0].text.strip()
date_4 = data_find[4].find_all("span" , {"class":"smaller"})
da_4 = date_4[0].text.strip()
date_5 = data_find[5].find_all("span" , {"class":"smaller"})
da_5 = date_5[0].text.strip()
date_6 = data_find[6].find_all("span" , {"class":"smaller"})
da_6 = date_6[0].text.strip()
date_7 = data_find[7].find_all("span" , {"class":"smaller"})
da_7 = date_7[0].text.strip()
date_8 = data_find[8].find_all("span" , {"class":"smaller"})
da_8 = date_8[0].text.strip()
date_9 = data_find[9].find_all("span" , {"class":"smaller"})
da_9 = date_9[0].text.strip()
date_10 = data_find[10].find_all("span" , {"class":"smaller"})
da_10 =date_10[0].text.strip()
date_11 = data_find[11].find_all("span" , {"class":"smaller"})
da_11 =date_11[0].text.strip()
date_12 = data_find[12].find_all("span" , {"class":"smaller"})
da_12 =date_12[0].text.strip()
date_13 = data_find[13].find_all("span" , {"class":"smaller"})
da_13 =date_13[0].text.strip()
date_14 = data_find[14].find_all("span" , {"class":"smaller"})
da_14 = date_14[0].text.strip()
date_15 = data_find[15].find_all("span" , {"class":"smaller"})
da_15 = date_15[0].text.strip()
date_16 = data_find[16].find_all("span" , {"class":"smaller"})
da_16 =date_16[0].text.strip()
date_17 = data_find[17].find_all("span" , {"class":"smaller"})
da_17 =date_17[0].text.strip()
date_18 = data_find[18].find_all("span" , {"class":"smaller"})
da_18 =date_18[0].text.strip()
date_19 = data_find[19].find_all("span" , {"class":"smaller"})
da_19 =date_19[0].text.strip()
date_20 = data_find[20].find_all("span" , {"class":"smaller"})
da_20 =date_20[0].text.strip()
date_21 = data_find[21].find_all("span" , {"class":"smaller"})
da_21 =date_21[0].text.strip()
date_22 = data_find[22].find_all("span" , {"class":"smaller"})
da_22 =date_22[0].text.strip()
date_23 = data_find[23].find_all("span" , {"class":"smaller"})
da_23 =date_23[0].text.strip()
date_24 = data_find[24].find_all("span" , {"class":"smaller"})
da_24 =date_24[0].text.strip()
date_25 = data_find[25].find_all("span" , {"class":"smaller"})
da_25 =date_25[0].text.strip()
date_26 = data_find[26].find_all("span" , {"class":"smaller"})
da_26 =date_26[0].text.strip()
date_27 = data_find[27].find_all("span" , {"class":"smaller"})
da_27 =date_27[0].text.strip()
date_28 = data_find[28].find_all("span" , {"class":"smaller"})
da_28 =date_28[0].text.strip()
date_29= data_find[29].find_all("span" , {"class":"smaller"})
da_29 =date_29[0].text.strip()
date_30 = data_find[30].find_all("span" , {"class":"smaller"})
da_30 = date_30[0].text.strip()

# %%
# scraping the socre of movie

# %%
# creating data frame

# %%
import pandas as pd

# %%
data = pd.DataFrame(columns=['name_of_movie', 'date_of_movie'])

# %%
data.loc[0] = [name_1 , da_1 ]
data.loc[1] = [name_2 , da_2 ]
data.loc[2] = [name_3 , da_3 ]
data.loc[3] = [name_4 , da_4 ]
data.loc[4] = [name_5 , da_5 ]
data.loc[5] = [name_6 , da_6 ]
data.loc[6] = [name_7 , da_7 ]
data.loc[7] = [name_8 , da_8 ]
data.loc[8] = [name_9 , da_9  ]
data.loc[9] = [name_10 , da_10 ]
data.loc[10] = [name_11 , da_11 ]
data.loc[11] = [name_12 , da_12 ]
data.loc[12] = [name_13 , da_13 ]
data.loc[13] = [name_14 , da_14 ]
data.loc[14] = [name_15 , da_15 ]
data.loc[15] = [name_16 , da_16 ]
data.loc[16] = [name_17 , da_17 ]
data.loc[17] = [name_18 , da_18 ]
data.loc[18] = [name_19 , da_19 ]
data.loc[19] = [name_20 , da_20 ]

# %%
data.loc[20] = [name_21 , da_21 ]
data.loc[21] = [name_22 , da_22 ]
data.loc[22] = [name_23 , da_23 ]
data.loc[23] = [name_24 , da_24 ]
data.loc[24] = [name_25 , da_25 ]
data.loc[25] = [name_26 , da_26 ]
data.loc[26] = [name_27 , da_27 ]
data.loc[27] = [name_28 , da_28 ]
data.loc[27] = [name_29 , da_29 ]
data.loc[28] = [name_30 , da_30 ]

# %%
import numpy as np

# %%
data
# Out:
#                       name_of_movie           date_of_movie
# 0                         I Came By  Streaming Aug 31, 2022
# 1                           Me Time  Streaming Aug 26, 2022
# 2                      The Gray Man  Streaming Jul 22, 2022
# 3                         Day Shift  Streaming Aug 12, 2022
# 4                 Love in the Villa   Streaming Sep 1, 2022
# 5                    Look Both Ways  Streaming Aug 17, 2022
# 6                         Uncharted  Streaming Apr 26, 2022
# 7                          365 Days  Streaming Jun 11, 2020
# 8                    Leave No Trace  Streaming Sep 25, 2018
# 9                       That's Amor  Streaming Aug 25, 2022
# 10                       Collateral   Streaming Aug 1, 2014
# 11                    Purple Hearts  Streaming Jul 29, 2022
# 12                           Hustle   Streaming Jun 8, 2022
# 13                    The Nice Guys   Streaming Aug 9, 2016
# 14                       Spiderhead  Streaming Jun 17, 2022
# ...
